# %%
import numpy as np
import pandas as pd
df=pd.read_csv(r'C:\Users\TARUN\Desktop\diabetes_India.csv')
df.head()

# %%
df.isnull().sum()

# %%
df.corr()

# %%
import seaborn as sb
import matplotlib.pyplot as plt
plt.figure(figsize=(10,15))
a=sb.heatmap(df.corr(),annot=True)
plt.show()

# %%
df1=pd.DataFrame(df)
df1
# Out:
#                                 Categories   India/States/UTs  \
# 0                                All India              India
# 1   MAJOR STATES (Population > 20 million)     Andhra Pradesh
# 2   MAJOR STATES (Population > 20 million)              Assam
# 3   MAJOR STATES (Population > 20 million)              Bihar
# 4   MAJOR STATES (Population > 20 million)        Chattisgarh
# 5   MAJOR STATES (Population > 20 million)            Gujarat
# 6   MAJOR STATES (Population > 20 million)            Haryana
# 7   MAJOR STATES (Population > 20 million)          Jharkhand
# 8   MAJOR STATES (Population > 20 million)          Karnataka
# 9   MAJOR STATES (Population > 20 million)             Kerala
# 10  MAJOR STATES (Population > 20 million)     Madhya Pradesh
# 11  MAJOR STATES (Population > 20 million)        Maharashtra
# 12  MAJOR STATES (Population > 20 million)             Odisha
# 13  MAJOR STATES (Population > 20 million)             Punjab
# ...

# %%
df['NFHS III(2005-06)-Number of women in age group 15-49 per 100-000 reported Diabetes-Total'].max()
# Out:
# 2549

# %% [markdown]
# # FOR WOMEN

# %%
df[['India/States/UTs']][df['NFHS III(2005-06)-Number of women in age group 15-49 per 100-000 reported Diabetes-Total']==df['NFHS III(2005-06)-Number of women in age group 15-49 per 100-000 reported Diabetes-Total'].max()]
# Out:
#   India/States/UTs
# 9           Kerala

# %%
df[['India/States/UTs']][df['NFHS III(2005-06)-Number of women in age group 15-49 per 100-000 reported Diabetes-Total']==df['NFHS III(2005-06)-Number of women in age group 15-49 per 100-000 reported Diabetes-Total'].min()]
# Out:
#    India/States/UTs
# 14        Rajasthan

# %% [markdown]
# # FOR MEN

# %%
df[['India/States/UTs']][df['NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Total']==df['NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Total'].max()]
# Out:
#   India/States/UTs
# 9           Kerala

# %%
df[['India/States/UTs']][df['NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Total']==df['NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Total'].min()]
# Out:
#      India/States/UTs
# 22  Jammu and Kashmir

# %% [markdown]
# # RURAL FOR MEN

# %%
df[['India/States/UTs']][df['NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Rural']==df['NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Rural'].max()]
# Out:
#    India/States/UTs
# 20              Goa

# %%
df[['India/States/UTs']][df['NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Rural']==df['NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Rural'].min()]
# Out:
#      India/States/UTs
# 19              Delhi
# 22  Jammu and Kashmir

# %% [markdown]
# # URBAN

# %%
df[['India/States/UTs']][df['NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Urban']==df['NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Urban'].max()]
# Out:
#   India/States/UTs
# 9           Kerala

# %%
df[['India/States/UTs']][df['NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Urban']==df['NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Urban'].min()]
# Out:
#    India/States/UTs
# 10   Madhya Pradesh

# %% [markdown]
# # URBAN FOR WOMEN

# %%
size = df['NFHS III(2005-06)-Number of women in age group 15-49 per 100-000 reported Diabetes-Total']
print(list(size))
# Out:
# [881, 838, 402, 1024, 659, 968, 1169, 652, 681, 2549, 558, 479, 556, 849, 282, 2188, 383, 1641, 537, 1692, 1921, 1048, 540, 1006, 910, 1189, 577, 1160, 1656, 825]

# %%
print(list(size)[9])
# Out:
# 2549

# %% [markdown]
# # FOR WOMEN

# %%
import numpy
import matplotlib.pyplot as plt

y = df['NFHS III(2005-06)-Number of women in age group 15-49 per 100-000 reported Diabetes-Total']
x = df['India/States/UTs']
plt.figure(figsize=(35,10))
plt.scatter(x, y)
plt.show()

# %% [markdown]
# # FOR MEN

# %%
import numpy
import matplotlib.pyplot as plt

y = df['NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Total']
x = df['India/States/UTs']
plt.figure(figsize=(35,10))
plt.scatter(x, y)
plt.show()

# %%
from itertools import cycle, islice
my_colors = list(islice(cycle(['b','purple']), None, len(df)))
df.plot.bar(x = 'India/States/UTs', y = ['NFHS III(2005-06)-Number of women in age group 15-49 per 100-000 reported Diabetes-Total', 'NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Total'],color=my_colors, rot = 40,figsize=(25,10))
# Out:
# <AxesSubplot:xlabel='India/States/UTs'>

# %% [markdown]
# From the data we got that mostly men are affected to Diabetis compared to Women in most of the states

# %% [markdown]
# # IN RURAL AREAS

# %%
from itertools import cycle, islice
my_colors = list(islice(cycle(['b','purple']), None, len(df)))
df.plot.bar(x = 'India/States/UTs', y = ['NFHS III(2005-06)-Number of women in age group 15-49 per 100-000 reported Diabetes-Rural','NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Total'],color=my_colors ,rot = 40,figsize=(25,10))
# Out:
# <AxesSubplot:xlabel='India/States/UTs'>

# %% [markdown]
# # IN URBAN AREAS

# %%
df.plot.bar(x = 'India/States/UTs', y = ['NFHS III(2005-06)-Number of women in age group 15-49 per 100-000 reported Diabetes-Rural','NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Urban'], rot = 40,figsize=(25,10))
# Out:
# <AxesSubplot:xlabel='India/States/UTs'>

# %%
df.groupby('NFHS III(2005-06)-Number of men in age group 15-49 per 100-000 reported Diabetes-Total').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# # Conclusion

# %% [markdown]
# As we have the past data 2005-06 From the data we have observed that the people in kerala are more affected with Diabetis. If we want to launch our product in the urban area then kerala is the first place we can make huge profits in that area . If we want to launch our product in Rural areas then the most Diabetis affected people are in Goa
